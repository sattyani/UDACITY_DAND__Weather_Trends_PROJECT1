# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('riyadh_global average.csv',index_col='year')

# %%
df.columns
# Out:
# Index(['Global Average', 'Riyadh Average'], dtype='object')

# %%
pd.set_option('display.max_rows', None)

# %%
df['global_ma_10']=df['Global Average'].rolling(10).mean()

# %%
df['riyadh_ma_10']=df['Riyadh Average'].rolling(10).mean()

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Average Temp')
plt.title('Temperature Tend (10 yrs MA)')
plt.plot(df['global_ma_10'],label='Global MA Average')
plt.plot(df['riyadh_ma_10'],label='Riyadh MA Average')
plt.legend(('global_ma_10','riyadh_ma_10'))
plt.legend(loc=10)
